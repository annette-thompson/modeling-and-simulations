# %%
def write_to_file(file_name, text):
    with open(file_name, 'w') as f:
        f.write(text)

file_name = "ODE_Function.txt"  # Name of the file you want to write to

# Add ODE Function script here starting with first dy term
text = """
dy(1,:) = P.k1_1r.*y(83,:) - P.k1_1f.*e1C.*y(1,:);

% Bicarbonate
dy(2,:) = P.k1_2r.*y(84,:) - P.k1_2f.*y(83,:).*y(2,:);

% Acetyl-CoA
dy(3,:) = P.k1_6r.*y(318,:) + P.k3_1r.*y(90,:) - P.k1_6f.*y(317,:).*y(3,:) - P.k3_1f.*e3.*y(3,:) - P.k10_4f.*e10.*y(3,:) + P.k10_4r.*y(305,:) - P.k8_4f.*e8.*y(3,:) + P.k8_4r.*y(308,:);

% ACP
dy(4,:) = P.k2_3r.*y(89,:) - P.k2_3f.*y(88,:).*y(4,:)...
    + P.kcat7(1).*y(101,:)...
    + P.kcat7(2).*y(116,:)...
    + P.kcat7(3).*y(131,:)...
    + P.kcat7(4).*y(146,:)...
    + P.kcat7(5).*y(161,:)...
    + P.kcat7(6).*y(176,:)...
    + P.kcat7(7).*y(191,:)...
    + P.kcat7(8).*y(206,:)...
    + P.kcat7(9).*y(221,:)...
    + P.kcat7(5).*y(230,:)...
    + P.kcat7(6).*y(245,:)...
    + P.kcat7(7).*y(260,:)...
    + P.kcat7(8).*y(275,:)...
    + P.kcat7(9).*y(290,:)...
    + P.k8_2f(1).*y(102,:)  - P.k8_2r(1).*y(103,:).*y(4,:)...
    + P.k8_2f(2).*y(117,:)  - P.k8_2r(2).*y(118,:).*y(4,:)...
    + P.k8_2f(3).*y(132,:)  - P.k8_2r(3).*y(133,:).*y(4,:)...
    + P.k8_2f(4).*y(147,:)  - P.k8_2r(4).*y(148,:).*y(4,:)...
    + P.k8_2f(5).*y(162,:)  - P.k8_2r(5).*y(163,:).*y(4,:)...
    + P.k8_2f(6).*y(177,:)  - P.k8_2r(6).*y(178,:).*y(4,:)...
    + P.k8_2f(7).*y(192,:)  - P.k8_2r(7).*y(193,:).*y(4,:)...
    + P.k8_2f(8).*y(207,:)  - P.k8_2r(8).*y(208,:).*y(4,:)...
    + P.k8_2f(5).*y(231,:)  - P.k8_2r(5).*y(232,:).*y(4,:)...
    + P.k8_2f(6).*y(246,:)  - P.k8_2r(6).*y(247,:).*y(4,:)...
    + P.k8_2f(7).*y(261,:)  - P.k8_2r(7).*y(262,:).*y(4,:)...
    + P.k8_2f(8).*y(276,:)  - P.k8_2r(8).*y(277,:).*y(4,:)...
    + P.k10_2f(1).*y(107,:) - P.k10_2r(1).*y(108,:).*y(4,:)...
    + P.k10_2f(2).*y(122,:) - P.k10_2r(2).*y(123,:).*y(4,:)...
    + P.k10_2f(3).*y(137,:) - P.k10_2r(3).*y(138,:).*y(4,:)...
    + P.k10_2f(4).*y(152,:) - P.k10_2r(4).*y(153,:).*y(4,:)...
    + P.k10_2f(5).*y(167,:) - P.k10_2r(5).*y(168,:).*y(4,:)...
    + P.k10_2f(6).*y(182,:) - P.k10_2r(6).*y(183,:).*y(4,:)...
    + P.k10_2f(7).*y(197,:) - P.k10_2r(7).*y(198,:).*y(4,:)...
    + P.k10_2f(8).*y(212,:) - P.k10_2r(8).*y(213,:).*y(4,:)...
    + P.k10_2f(5).*y(236,:) - P.k10_2r(5).*y(237,:).*y(4,:)...
    + P.k10_2f(6).*y(251,:) - P.k10_2r(6).*y(252,:).*y(4,:)...
    + P.k10_2f(7).*y(266,:) - P.k10_2r(7).*y(267,:).*y(4,:)...
    + P.k10_2f(8).*y(281,:) - P.k10_2r(8).*y(282,:).*y(4,:)...
    + P.k10_2f(4).*y(302,:) - P.k10_2r(4).*y(303,:).*y(4,:)...
    + P.k3_inh_r.*y(293,:)  - P.k3_inh_f.*e3.*y(4,:)...
    + P.k4_inh_r.*y(294,:)  - P.k4_inh_f.*e4.*y(4,:)...
    + P.k5_inh_r.*y(295,:)  - P.k5_inh_f.*e5.*y(4,:)...
    + P.k6_inh_r.*y(296,:)  - P.k6_inh_f.*e6.*y(4,:)...
    + P.k7_inh_r.*y(297,:)  - P.k7_inh_f.*e7.*y(4,:)...
    + P.k8_inh_r.*y(298,:)  - P.k8_inh_f.*e8.*y(4,:)...
    + P.k9_inh_r.*y(299,:)  - P.k9_inh_f.*e9.*y(4,:)...
    + P.k10_inh_r.*y(300,:) - P.k10_inh_f.*e10.*y(4,:)...
    + P.k10_9f.*y(313,:) - P.k10_9r.*y(306,:).*y(4,:)...
    + P.k8_9f.*y(315,:) - P.k8_9r.*y(309,:).*y(4,:); 

% NADPH
dy(5,:) = P.k4_1r(1).*y(93,:) - P.k4_1f(1).*e4.*y(5,:); 

% NADH
dy(6,:) = P.k6_1r(1).*y(94,:) - P.k6_1f(1).*e6.*y(6,:); 

% ADP
dy(7,:) = P.kcat1_1.*y(84,:);

% Malonyl-CoA kcat1_2
dy(8,:) = P.kcat1_2.*y(318,:) + P.k2_1r.*y(87,:) - P.k2_1f.*e2.*y(8,:); 

% CoA
dy(9,:) = P.k2_2f.*y(87,:) - P.k2_2r.*y(88,:).*y(9,:)...
    + P.k3_2f.*y(90,:) - P.k3_2r.*y(91,:).*y(9,:)...
    + P.k8_5f.*y(308,:) - P.k8_5r*y(309,:).*y(9,:)...
    + P.k10_5f.*y(305,:) - P.k10_5r.*y(306,:).*y(9,:);

% Malonyl-ACP
dy(10,:) = P.k2_4f.*y(89,:) + P.k3_3r.*y(92,:) - P.k2_4r.*e2.*y(10,:) - P.k3_3f.*y(91,:).*y(10,:)...
    + P.k8_3r(1).*y(104,:) - P.k8_3f(1).*y(103,:).*y(10,:)...
    + P.k8_3r(2).*y(119,:) - P.k8_3f(2).*y(118,:).*y(10,:)...
    + P.k8_3r(3).*y(134,:) - P.k8_3f(3).*y(133,:).*y(10,:)...
    + P.k8_3r(4).*y(149,:) - P.k8_3f(4).*y(148,:).*y(10,:)...
    + P.k8_3r(5).*y(164,:) - P.k8_3f(5).*y(163,:).*y(10,:)...
    + P.k8_3r(6).*y(179,:) - P.k8_3f(6).*y(178,:).*y(10,:)...
    + P.k8_3r(7).*y(194,:) - P.k8_3f(7).*y(193,:).*y(10,:)...
    + P.k8_3r(8).*y(209,:) - P.k8_3f(8).*y(208,:).*y(10,:)...
    + P.k8_3r(5).*y(233,:) - P.k8_3f(5).*y(232,:).*y(10,:)...
    + P.k8_3r(6).*y(248,:) - P.k8_3f(6).*y(247,:).*y(10,:)...
    + P.k8_3r(7).*y(263,:) - P.k8_3f(7).*y(262,:).*y(10,:)...
    + P.k8_3r(8).*y(278,:) - P.k8_3f(8).*y(277,:).*y(10,:)...
    + P.k8_6r.*y(310,:) - P.k8_6f.*y(309,:).*y(10,:)...
    + P.k8_7r.*y(314,:) - P.k8_7f.*e8.*y(10,:)...
    + P.k10_3r(1).*y(109,:) - P.k10_3f(1).*y(108,:).*y(10,:)...
    + P.k10_3r(2).*y(124,:) - P.k10_3f(2).*y(123,:).*y(10,:)...
    + P.k10_3r(3).*y(139,:) - P.k10_3f(3).*y(138,:).*y(10,:)...
    + P.k10_3r(4).*y(154,:) - P.k10_3f(4).*y(153,:).*y(10,:)...
    + P.k10_3r(5).*y(169,:) - P.k10_3f(5).*y(168,:).*y(10,:)...
    + P.k10_3r(6).*y(184,:) - P.k10_3f(6).*y(183,:).*y(10,:)...
    + P.k10_3r(7).*y(199,:) - P.k10_3f(7).*y(198,:).*y(10,:)...
    + P.k10_3r(8).*y(214,:) - P.k10_3f(8).*y(213,:).*y(10,:)...
    + P.k10_3r(5).*y(238,:) - P.k10_3f(5).*y(237,:).*y(10,:)...
    + P.k10_3r(6).*y(253,:) - P.k10_3f(6).*y(252,:).*y(10,:)...
    + P.k10_3r(7).*y(268,:) - P.k10_3f(7).*y(267,:).*y(10,:)...
    + P.k10_3r(8).*y(283,:) - P.k10_3f(8).*y(282,:).*y(10,:)...
    + P.k10_3r(4).*y(304,:) - P.k10_3f(4).*y(303,:).*y(10,:)...
    + P.k10_6r.*y(307,:) - P.k10_6f.*y(306,:).*y(10,:)...
    + P.k10_7r.*y(311,:) - P.k10_7f.*e10.*y(10,:);

% CO2
dy(11,:) = P.kcat3.*y(92,:) + P.kcat8(1).*y(104,:) + P.kcat8(2).*y(119,:) + P.kcat8(3).*y(134,:) + P.kcat8(4).*y(149,:)...
    + P.kcat8(5).*y(164,:) + P.kcat8(6).*y(179,:) + P.kcat8(7).*y(194,:) + P.kcat8(8).*y(209,:)...
    + P.kcat8_un(5).*y(233,:) + P.kcat8_un(6).*y(248,:) + P.kcat8_un(7).*y(263,:) + P.kcat8_un(8).*y(278,:)...
    + P.kcat8_H.*y(310,:) + P.kcat8_CO2.*y(314,:)...
    + P.kcat10(1).*y(109,:) + P.kcat10(2).*y(124,:) + P.kcat10(3).*y(139,:) + P.kcat10(4).*y(154,:)...
    + P.kcat10(5).*y(169,:) + P.kcat10(6).*y(184,:) + P.kcat10(7).*y(199,:) + P.kcat10(8).*y(214,:)...
    + P.kcat10_un(4).*y(304,:) + P.kcat10_un(5).*y(238,:) + P.kcat10_un(6).*y(253,:) + P.kcat10_un(7).*y(268,:) + P.kcat10_un(8).*y(283,:)...
    + P.kcat10_H.*y(307,:) + P.kcat10_CO2.*y(311,:);

% C4 B-ketoacyl-ACP (FabD - FabG)
dy(12,:) = P.kcat3.*y(92,:) + P.k4_2r(1).*y(97,:) - P.k4_2f(1).*y(93,:).*y(12,:) + P.kcat8_H.*y(310,:) + P.kcat10_H.*y(307,:); 

% C2n (n=3:10) B-ketoacyl-ACPs (FabF + FabB - FabG)
dy(17,:) = P.kcat8(1).*y(104,:) + P.kcat10(1).*y(109,:) + P.k4_2r(2).*y(112,:) - P.k4_2f(2).*y(93,:).*y(17,:);
dy(22,:) = P.kcat8(2).*y(119,:) + P.kcat10(2).*y(124,:) + P.k4_2r(3).*y(127,:) - P.k4_2f(3).*y(93,:).*y(22,:);
dy(27,:) = P.kcat8(3).*y(134,:) + P.kcat10(3).*y(139,:) + P.k4_2r(4).*y(142,:) - P.k4_2f(4).*y(93,:).*y(27,:);
dy(33,:) = P.kcat8(4).*y(149,:) + P.kcat10(4).*y(154,:) + P.k4_2r(5).*y(157,:) - P.k4_2f(5).*y(93,:).*y(33,:);
dy(43,:) = P.kcat8(5).*y(164,:) + P.kcat10(5).*y(169,:) + P.k4_2r(6).*y(172,:) - P.k4_2f(6).*y(93,:).*y(43,:);
dy(53,:) = P.kcat8(6).*y(179,:) + P.kcat10(6).*y(184,:) + P.k4_2r(7).*y(187,:) - P.k4_2f(7).*y(93,:).*y(53,:);
dy(63,:) = P.kcat8(7).*y(194,:) + P.kcat10(7).*y(199,:) + P.k4_2r(8).*y(202,:) - P.k4_2f(8).*y(93,:).*y(63,:);
dy(73,:) = P.kcat8(8).*y(209,:) + P.kcat10(8).*y(214,:) + P.k4_2r(9).*y(217,:) - P.k4_2f(9).*y(93,:).*y(73,:);

% C2n:1 (n=6:10) B-ketoacyl-ACPs (FabF + FabB - FabG)
dy(38,:) =                           P.kcat10_un(4).*y(304,:) + P.k4_2r(5).*y(226,:) - P.k4_2f(5).*y(93,:).*y(38,:);
dy(48,:) = P.kcat8_un(5).*y(233,:) + P.kcat10_un(5).*y(238,:) + P.k4_2r(6).*y(241,:) - P.k4_2f(6).*y(93,:).*y(48,:);
dy(58,:) = P.kcat8_un(6).*y(248,:) + P.kcat10_un(6).*y(253,:) + P.k4_2r(7).*y(256,:) - P.k4_2f(7).*y(93,:).*y(58,:);
dy(68,:) = P.kcat8_un(7).*y(263,:) + P.kcat10_un(7).*y(268,:) + P.k4_2r(8).*y(271,:) - P.k4_2f(8).*y(93,:).*y(68,:);
dy(78,:) = P.kcat8_un(8).*y(278,:) + P.kcat10_un(8).*y(283,:) + P.k4_2r(9).*y(286,:) - P.k4_2f(9).*y(93,:).*y(78,:);

% C2n (n=2:10) B-hydroxyacyl-ACPs (FabG - FabZ - FabA)
dy(13,:) = P.kcat4(1).*y(97,:)  + P.k5_1r(1).*y(98,:)  - P.k5_1f(1).*e5.*y(13,:)  + P.k9_1r(1).*y(105,:)  - P.k9_1f(1).*e9.*y(13,:);
dy(18,:) = P.kcat4(2).*y(112,:) + P.k5_1r(2).*y(113,:) - P.k5_1f(2).*e5.*y(18,:)  + P.k9_1r(2).*y(120,:)  - P.k9_1f(2).*e9.*y(18,:);
dy(23,:) = P.kcat4(3).*y(127,:) + P.k5_1r(3).*y(128,:) - P.k5_1f(3).*e5.*y(23,:)  + P.k9_1r(3).*y(135,:)  - P.k9_1f(3).*e9.*y(23,:);
dy(28,:) = P.kcat4(4).*y(142,:) + P.k5_1r(4).*y(143,:) - P.k5_1f(4).*e5.*y(28,:) + P.k9_1r(4).*y(150,:) - P.k9_1f(4).*e9.*y(28,:);
dy(34,:) = P.kcat4(5).*y(157,:) + P.k5_1r(5).*y(158,:) - P.k5_1f(5).*e5.*y(34,:) + P.k9_1r(5).*y(165,:) - P.k9_1f(5).*e9.*y(34,:);
dy(44,:) = P.kcat4(6).*y(172,:) + P.k5_1r(6).*y(173,:) - P.k5_1f(6).*e5.*y(44,:) + P.k9_1r(6).*y(180,:) - P.k9_1f(6).*e9.*y(44,:);
dy(54,:) = P.kcat4(7).*y(187,:) + P.k5_1r(7).*y(188,:) - P.k5_1f(7).*e5.*y(54,:) + P.k9_1r(7).*y(195,:) - P.k9_1f(7).*e9.*y(54,:);
dy(64,:) = P.kcat4(8).*y(202,:) + P.k5_1r(8).*y(203,:) - P.k5_1f(8).*e5.*y(64,:) + P.k9_1r(8).*y(210,:) - P.k9_1f(8).*e9.*y(64,:);
dy(74,:) = P.kcat4(9).*y(217,:) + P.k5_1r(9).*y(218,:) - P.k5_1f(9).*e5.*y(74,:) + P.k9_1r(9).*y(222,:) - P.k9_1f(9).*e9.*y(74,:);

% C2n:1 (n=6:10) B-hydroxyacyl-ACPs (FabG - FabZ - FabA)
dy(39,:) = P.kcat4(5).*y(226,:) + P.k5_1r(5).*y(227,:) - P.k5_1f(5).*e5.*y(39,:) + P.k9_1r_un(5).*y(234,:) - P.k9_1f_un(5).*e9.*y(39,:);
dy(49,:) = P.kcat4(6).*y(241,:) + P.k5_1r(6).*y(242,:) - P.k5_1f(6).*e5.*y(49,:) + P.k9_1r_un(6).*y(249,:) - P.k9_1f_un(6).*e9.*y(49,:);
dy(59,:) = P.kcat4(7).*y(256,:) + P.k5_1r(7).*y(257,:) - P.k5_1f(7).*e5.*y(59,:) + P.k9_1r_un(7).*y(264,:) - P.k9_1f_un(7).*e9.*y(59,:);
dy(69,:) = P.kcat4(8).*y(271,:) + P.k5_1r(8).*y(272,:) - P.k5_1f(8).*e5.*y(69,:) + P.k9_1r_un(8).*y(279,:) - P.k9_1f_un(8).*e9.*y(69,:);
dy(79,:) = P.kcat4(9).*y(286,:) + P.k5_1r(9).*y(287,:) - P.k5_1f(9).*e5.*y(79,:) + P.k9_1r_un(9).*y(291,:) - P.k9_1f_un(9).*e9.*y(79,:);

% C2n (n=2:10) Enoyl-Acyl-ACPs (FabZ + FabA - FabI) 
dy(14,:) = P.k5_3f(1).*y(99,:)  - P.k5_3r(1).*e5.*y(14,:) + P.k9_3f(1).*y(106,:) - P.k9_3r(1).*e9.*y(14,:) + P.k6_2r(1).*y(100,:) - P.k6_2f(1).*y(94,:).*y(14,:);
dy(19,:) = P.k5_3f(2).*y(114,:) - P.k5_3r(2).*e5.*y(19,:) + P.k9_3f(2).*y(121,:) - P.k9_3r(2).*e9.*y(19,:) + P.k6_2r(2).*y(115,:) - P.k6_2f(2).*y(94,:).*y(19,:);
dy(24,:) = P.k5_3f(3).*y(129,:) - P.k5_3r(3).*e5.*y(24,:) + P.k9_3f(3).*y(136,:) - P.k9_3r(3).*e9.*y(24,:) + P.k6_2r(3).*y(130,:) - P.k6_2f(3).*y(94,:).*y(24,:);
dy(29,:) = P.k5_3f(4).*y(144,:) - P.k5_3r(4).*e5.*y(29,:) + P.k9_3f(4).*y(151,:) - P.k9_3r(4).*e9.*y(29,:) + P.k6_2r(4).*y(145,:) - P.k6_2f(4).*y(94,:).*y(29,:);
dy(35,:) = P.k5_3f(5).*y(159,:) - P.k5_3r(5).*e5.*y(35,:) + P.k9_3f(5).*y(166,:) - P.k9_3r(5).*e9.*y(35,:) + P.k6_2r(5).*y(160,:) - P.k6_2f(5).*y(94,:).*y(35,:);
dy(45,:) = P.k5_3f(6).*y(174,:) - P.k5_3r(6).*e5.*y(45,:) + P.k9_3f(6).*y(181,:) - P.k9_3r(6).*e9.*y(45,:) + P.k6_2r(6).*y(175,:) - P.k6_2f(6).*y(94,:).*y(45,:);
dy(55,:) = P.k5_3f(7).*y(189,:) - P.k5_3r(7).*e5.*y(55,:) + P.k9_3f(7).*y(196,:) - P.k9_3r(7).*e9.*y(55,:) + P.k6_2r(7).*y(190,:) - P.k6_2f(7).*y(94,:).*y(55,:);
dy(65,:) = P.k5_3f(8).*y(204,:) - P.k5_3r(8).*e5.*y(65,:) + P.k9_3f(8).*y(211,:) - P.k9_3r(8).*e9.*y(65,:) + P.k6_2r(8).*y(205,:) - P.k6_2f(8).*y(94,:).*y(65,:);
dy(75,:) = P.k5_3f(9).*y(219,:) - P.k5_3r(9).*e5.*y(75,:) + P.k9_3f(9).*y(223,:) - P.k9_3r(9).*e9.*y(75,:) + P.k6_2r(9).*y(220,:) - P.k6_2f(9).*y(94,:).*y(75,:);

% C10 cis-3-Enoyl-Acyl-ACP (FabA - FabB)
dy(32,:) = P.k9_3f_un(4).*y(301,:) - P.k9_3r_un(4).*e9.*y(32,:) + P.k10_1r(4).*y(302,:) - P.k10_1f(4).*e10.*y(32,:);

% C2n:1 (n=6:10) Enoyl-Acyl-ACPs  (FabZ + FabA - FabI)
dy(40,:) = P.k5_3f(5).*y(228,:) - P.k5_3r(5).*e5.*y(40,:) + P.k9_3f(5).*y(235,:) - P.k9_3r(5).*e9.*y(40,:) + P.k6_2r(5).*y(229,:) - P.k6_2f(5).*y(94,:).*y(40,:);
dy(50,:) = P.k5_3f(6).*y(243,:) - P.k5_3r(6).*e5.*y(50,:) + P.k9_3f(6).*y(250,:) - P.k9_3r(6).*e9.*y(50,:) + P.k6_2r(6).*y(244,:) - P.k6_2f(6).*y(94,:).*y(50,:);
dy(60,:) = P.k5_3f(7).*y(258,:) - P.k5_3r(7).*e5.*y(60,:) + P.k9_3f(7).*y(265,:) - P.k9_3r(7).*e9.*y(60,:) + P.k6_2r(7).*y(259,:) - P.k6_2f(7).*y(94,:).*y(60,:);
dy(70,:) = P.k5_3f(8).*y(273,:) - P.k5_3r(8).*e5.*y(70,:) + P.k9_3f(8).*y(280,:) - P.k9_3r(8).*e9.*y(70,:) + P.k6_2r(8).*y(274,:) - P.k6_2f(8).*y(94,:).*y(70,:);
dy(80,:) = P.k5_3f(9).*y(288,:) - P.k5_3r(9).*e5.*y(80,:) + P.k9_3f(9).*y(292,:) - P.k9_3r(9).*e9.*y(80,:) + P.k6_2r(9).*y(289,:) - P.k6_2f(9).*y(94,:).*y(80,:);

% C2n (n=2:10) Acyl-ACPs (FabI - TesA - FabF - FabB - FabH)
dy(15,:) = P.kcat6(1).*y(100,:) + P.k7_1r(1).*y(101,:) + P.k8_1r(1).*y(102,:) + P.k10_1r(1).*y(107,:) - P.k7_1f(1).*e7.*y(15,:) - P.k8_1f(1).*e8.*y(15,:) - P.k10_1f(1).*e10.*y(15,:) - P.k3_4f(1).*e3.*y(15,:) + P.k3_4r(1).*y(95,:)  - P.k3_5f(1).*y(91,:).*y(15,:) + P.k3_5r(1).*y(96,:);
dy(20,:) = P.kcat6(2).*y(115,:) + P.k7_1r(2).*y(116,:) + P.k8_1r(2).*y(117,:) + P.k10_1r(2).*y(122,:) - P.k7_1f(2).*e7.*y(20,:) - P.k8_1f(2).*e8.*y(20,:) - P.k10_1f(2).*e10.*y(20,:) - P.k3_4f(2).*e3.*y(20,:) + P.k3_4r(2).*y(110,:) - P.k3_5f(2).*y(91,:).*y(20,:) + P.k3_5r(2).*y(111,:);
dy(25,:) = P.kcat6(3).*y(130,:) + P.k7_1r(3).*y(131,:) + P.k8_1r(3).*y(132,:) + P.k10_1r(3).*y(137,:) - P.k7_1f(3).*e7.*y(25,:) - P.k8_1f(3).*e8.*y(25,:) - P.k10_1f(3).*e10.*y(25,:) - P.k3_4f(3).*e3.*y(25,:) + P.k3_4r(3).*y(125,:) - P.k3_5f(3).*y(91,:).*y(25,:) + P.k3_5r(3).*y(126,:);
dy(30,:) = P.kcat6(4).*y(145,:) + P.k7_1r(4).*y(146,:) + P.k8_1r(4).*y(147,:) + P.k10_1r(4).*y(152,:) - P.k7_1f(4).*e7.*y(30,:) - P.k8_1f(4).*e8.*y(30,:) - P.k10_1f(4).*e10.*y(30,:) - P.k3_4f(4).*e3.*y(30,:) + P.k3_4r(4).*y(140,:) - P.k3_5f(4).*y(91,:).*y(30,:) + P.k3_5r(4).*y(141,:);
dy(36,:) = P.kcat6(5).*y(160,:) + P.k7_1r(5).*y(161,:) + P.k8_1r(5).*y(162,:) + P.k10_1r(5).*y(167,:) - P.k7_1f(5).*e7.*y(36,:) - P.k8_1f(5).*e8.*y(36,:) - P.k10_1f(5).*e10.*y(36,:) - P.k3_4f(5).*e3.*y(36,:) + P.k3_4r(5).*y(155,:) - P.k3_5f(5).*y(91,:).*y(36,:) + P.k3_5r(5).*y(156,:);
dy(46,:) = P.kcat6(6).*y(175,:) + P.k7_1r(6).*y(176,:) + P.k8_1r(6).*y(177,:) + P.k10_1r(6).*y(182,:) - P.k7_1f(6).*e7.*y(46,:) - P.k8_1f(6).*e8.*y(46,:) - P.k10_1f(6).*e10.*y(46,:) - P.k3_4f(6).*e3.*y(46,:) + P.k3_4r(6).*y(170,:) - P.k3_5f(6).*y(91,:).*y(46,:) + P.k3_5r(6).*y(171,:);
dy(56,:) = P.kcat6(7).*y(190,:) + P.k7_1r(7).*y(191,:) + P.k8_1r(7).*y(192,:) + P.k10_1r(7).*y(197,:) - P.k7_1f(7).*e7.*y(56,:) - P.k8_1f(7).*e8.*y(56,:) - P.k10_1f(7).*e10.*y(56,:) - P.k3_4f(7).*e3.*y(56,:) + P.k3_4r(7).*y(185,:) - P.k3_5f(7).*y(91,:).*y(56,:) + P.k3_5r(7).*y(186,:);
dy(66,:) = P.kcat6(8).*y(205,:) + P.k7_1r(8).*y(206,:) + P.k8_1r(8).*y(207,:) + P.k10_1r(8).*y(212,:) - P.k7_1f(8).*e7.*y(66,:) - P.k8_1f(8).*e8.*y(66,:) - P.k10_1f(8).*e10.*y(66,:) - P.k3_4f(8).*e3.*y(66,:) + P.k3_4r(8).*y(200,:) - P.k3_5f(8).*y(91,:).*y(66,:) + P.k3_5r(8).*y(201,:);

% C2n (n=10) Acyl-ACPs (FabI - TesA - FabH)
dy(76,:) = P.kcat6(9).*y(220,:)  + P.k7_1r(9).*y(221,:) - P.k7_1f(9).*e7.*y(76,:) - P.k3_4f(9).*e3.*y(76,:) + P.k3_4r(9).*y(215,:) - P.k3_5f(9).*y(91,:).*y(76,:) + P.k3_5r(9).*y(216,:);

% C2n:1 (n=6:10) Acyl-ACPs (FabI - TesA - FabF - FabB - FabH)
dy(41,:) = P.kcat6(5).*y(229,:) + P.k7_1r(5).*y(230,:) + P.k8_1r(5).*y(231,:) + P.k10_1r(5).*y(236,:) - P.k7_1f(5).*e7.*y(41,:) - P.k8_1f(5).*e8.*y(41,:) - P.k10_1f(5).*e10.*y(41,:) - P.k3_4f(5).*e3.*y(41,:) + P.k3_4r(5).*y(224,:) - P.k3_5f(5).*y(91,:).*y(41,:) + P.k3_5r(5).*y(225,:);
dy(51,:) = P.kcat6(6).*y(244,:) + P.k7_1r(6).*y(245,:) + P.k8_1r(6).*y(246,:) + P.k10_1r(6).*y(251,:) - P.k7_1f(6).*e7.*y(51,:) - P.k8_1f(6).*e8.*y(51,:) - P.k10_1f(6).*e10.*y(51,:) - P.k3_4f(6).*e3.*y(51,:) + P.k3_4r(6).*y(239,:) - P.k3_5f(6).*y(91,:).*y(51,:) + P.k3_5r(6).*y(240,:);
dy(61,:) = P.kcat6(7).*y(259,:) + P.k7_1r(7).*y(260,:) + P.k8_1r(7).*y(261,:) + P.k10_1r(7).*y(266,:) - P.k7_1f(7).*e7.*y(61,:) - P.k8_1f(7).*e8.*y(61,:) - P.k10_1f(7).*e10.*y(61,:) - P.k3_4f(7).*e3.*y(61,:) + P.k3_4r(7).*y(254,:) - P.k3_5f(7).*y(91,:).*y(61,:) + P.k3_5r(7).*y(255,:);
dy(71,:) = P.kcat6(8).*y(274,:) + P.k7_1r(8).*y(275,:) + P.k8_1r(8).*y(276,:) + P.k10_1r(8).*y(281,:) - P.k7_1f(8).*e7.*y(71,:) - P.k8_1f(8).*e8.*y(71,:) - P.k10_1f(8).*e10.*y(71,:) - P.k3_4f(8).*e3.*y(71,:) + P.k3_4r(8).*y(269,:) - P.k3_5f(8).*y(91,:).*y(71,:) + P.k3_5r(8).*y(270,:);

% C2n:1 (n=10) Acyl-ACPs (FabI - TesA - FabH)
dy(81,:) = P.kcat6(9).*y(289,:) + P.k7_1r(9).*y(290,:) - P.k7_1f(9).*e7.*y(81,:) - P.k3_4f(9).*e3.*y(81,:) + P.k3_4r(9).*y(284,:) - P.k3_5f(9).*y(91,:).*y(81,:) + P.k3_5r(9).*y(285,:);

% Fatty Acids
dy(16,:) = P.kcat7(1).*y(101,:);
dy(21,:) = P.kcat7(2).*y(116,:);
dy(26,:) = P.kcat7(3).*y(131,:);
dy(31,:) = P.kcat7(4).*y(146,:);
dy(37,:) = P.kcat7(5).*y(161,:);
dy(47,:) = P.kcat7(6).*y(176,:);
dy(57,:) = P.kcat7(7).*y(191,:);
dy(67,:) = P.kcat7(8).*y(206,:);
dy(77,:) = P.kcat7(9).*y(221,:);

% Fatty Acids (unsaturated)
dy(42,:) = P.kcat7(5).*y(230,:);
dy(52,:) = P.kcat7(6).*y(245,:);
dy(62,:) = P.kcat7(7).*y(260,:);
dy(72,:) = P.kcat7(8).*y(275,:);
dy(82,:) = P.kcat7(9).*y(290,:);

% BC-ATP k1_1
dy(83,:) = P.k1_1f.*e1C.*y(1,:) + P.k1_2r.*y(84,:) - P.k1_1r.*y(83,:) - P.k1_2f.*y(83,:).*y(2,:);

% BC-ATP-HCO3 k1_2
dy(84,:) = P.k1_2f.*y(83,:).*y(2,:) - P.k1_2r.*y(84,:) - P.kcat1_1.*y(84,:);

% BC-Pi-HCO3 kcat1_1
dy(85,:) = P.kcat1_1.*y(84,:) + P.k1_3r.*y(319,:) - P.k1_3f.*e1B.*y(85,:);

% BC-Pi-HCO3-BCCP-Biotin k1_3
dy(319,:) = P.k1_3f.*e1B.*y(85,:) - P.k1_3r.*y(319,:) - P.kcat1_3.*y(319,:);

% BCCP-Biotin-CO2 kcat1_3
dy(86,:) = P.kcat1_1.*y(319,:) + P.k1_4r.*y(316,:) - P.k1_4f.*e1AD.*y(86,:);

% CT-BCCP-Biotin-CO2 k1_4
dy(316,:) = P.k1_4f.*e1AD.*y(86,:) + P.k1_5r.*e1B.*y(317,:) - P.k1_4r.*y(316,:) - P.k1_5f.*y(316,:);

% CT* k1_5
dy(317,:) = P.k1_5f.*y(316,:) + P.k1_6r.*y(318,:) - P.k1_5r.*e1B.*y(317,:) - P.k1_6f.*y(317,:).*y(3,:);

% CT*-AcCoA k1_6
dy(318,:) = P.k1_6f.*y(317,:).*y(3,:) - P.k1_6r.*y(318,:) - P.kcat1_2.*e1AD.*y(8,:);

% FabD-Malonyl-CoA
dy(87,:) = P.k2_1f.*e2.*y(8,:) + P.k2_2r.*y(88,:).*y(9,:) - P.k2_1r.*y(87,:) - P.k2_2f.*y(87,:); 

% FabD*
dy(88,:) = P.k2_2f.*y(87,:) + P.k2_3r.*y(89,:) - P.k2_2r.*y(88,:).*y(9,:) - P.k2_3f.*y(88,:).*y(4,:);

% FabD*-ACP
dy(89,:) = P.k2_3f.*y(88,:).*y(4,:) + P.k2_4r.*e2.*y(10,:) - P.k2_3r.*y(89,:) - P.k2_4f.*y(89,:);

% FabH-Acetyl-CoA
dy(90,:) = P.k3_1f.*e3.*y(3,:) + P.k3_2r.*y(91,:).*y(9,:) - P.k3_1r.*y(90,:) - P.k3_2f.*y(90,:); 

% FabH*
dy(91,:) = P.k3_2f.*y(90,:) + P.k3_3r.*y(92,:) - P.k3_2r.*y(91,:).*y(9,:) - P.k3_3f.*y(91,:).*y(10,:)...
 + P.k3_5r(1).*y(96,:) - P.k3_5f(1).*y(91,:).*y(15,:)...
 + P.k3_5r(2).*y(111,:) - P.k3_5f(2).*y(91,:).*y(20,:)...
 + P.k3_5r(3).*y(126,:) - P.k3_5f(3).*y(91,:).*y(25,:)...
 + P.k3_5r(4).*y(141,:) - P.k3_5f(4).*y(91,:).*y(30,:)...
 + P.k3_5r(5).*y(156,:) - P.k3_5f(5).*y(91,:).*y(36,:)...
 + P.k3_5r(6).*y(171,:) - P.k3_5f(6).*y(91,:).*y(46,:)...
 + P.k3_5r(7).*y(186,:) - P.k3_5f(7).*y(91,:).*y(56,:)...
 + P.k3_5r(8).*y(201,:) - P.k3_5f(8).*y(91,:).*y(66,:)...
 + P.k3_5r(9).*y(216,:) - P.k3_5f(9).*y(91,:).*y(76,:)...
 + P.k3_5r(5).*y(225,:) - P.k3_5f(5).*y(91,:).*y(41,:)...
 + P.k3_5r(6).*y(240,:) - P.k3_5f(6).*y(91,:).*y(51,:)...
 + P.k3_5r(7).*y(255,:) - P.k3_5f(7).*y(91,:).*y(61,:)...
 + P.k3_5r(8).*y(270,:) - P.k3_5f(8).*y(91,:).*y(71,:)...
 + P.k3_5r(9).*y(285,:) - P.k3_5f(9).*y(91,:).*y(81,:);

% FabH*-Malonyl-ACP
dy(92,:) = P.k3_3f.*y(91,:).*y(10,:) - P.k3_3r.*y(92,:) - P.kcat3.*y(92,:); 

% FabG-NADPH
dy(93,:) = P.k4_1f(1).*e4.*y(5,:) - P.k4_1r(1).*y(93,:)...
 + P.k4_2r(1).*y(97,:) - P.k4_2f(1).*y(93,:).*y(12,:)...
 + P.k4_2r(2).*y(112,:) - P.k4_2f(2).*y(93,:).*y(17,:)...
 + P.k4_2r(3).*y(127,:) - P.k4_2f(3).*y(93,:).*y(22,:)...
 + P.k4_2r(4).*y(142,:) - P.k4_2f(4).*y(93,:).*y(27,:)...
 + P.k4_2r(5).*y(157,:) - P.k4_2f(5).*y(93,:).*y(33,:)...
 + P.k4_2r(6).*y(172,:) - P.k4_2f(6).*y(93,:).*y(43,:)...
 + P.k4_2r(7).*y(187,:) - P.k4_2f(7).*y(93,:).*y(53,:)...
 + P.k4_2r(8).*y(202,:) - P.k4_2f(8).*y(93,:).*y(63,:)...
 + P.k4_2r(9).*y(217,:) - P.k4_2f(9).*y(93,:).*y(73,:)...
 + P.k4_2r(5).*y(226,:) - P.k4_2f(5).*y(93,:).*y(38,:)...
 + P.k4_2r(6).*y(241,:) - P.k4_2f(6).*y(93,:).*y(48,:)...
 + P.k4_2r(7).*y(256,:) - P.k4_2f(7).*y(93,:).*y(58,:)...
 + P.k4_2r(8).*y(271,:) - P.k4_2f(8).*y(93,:).*y(68,:)...
 + P.k4_2r(9).*y(286,:) - P.k4_2f(9).*y(93,:).*y(78,:); 

% FabG-NADPH-(C2n (n=2:10) B-ketoacyl-ACPs)
dy(97,:) = P.k4_2f(1).*y(93,:).*y(12,:) - P.k4_2r(1).*y(97,:) - P.kcat4(1).*y(97,:);
dy(112,:) = P.k4_2f(2).*y(93,:).*y(17,:) - P.k4_2r(2).*y(112,:) - P.kcat4(2).*y(112,:);
dy(127,:) = P.k4_2f(3).*y(93,:).*y(22,:) - P.k4_2r(3).*y(127,:) - P.kcat4(3).*y(127,:);
dy(142,:) = P.k4_2f(4).*y(93,:).*y(27,:) - P.k4_2r(4).*y(142,:) - P.kcat4(4).*y(142,:);
dy(157,:) = P.k4_2f(5).*y(93,:).*y(33,:) - P.k4_2r(5).*y(157,:) - P.kcat4(5).*y(157,:);
dy(172,:) = P.k4_2f(6).*y(93,:).*y(43,:) - P.k4_2r(6).*y(172,:) - P.kcat4(6).*y(172,:);
dy(187,:) = P.k4_2f(7).*y(93,:).*y(53,:) - P.k4_2r(7).*y(187,:) - P.kcat4(7).*y(187,:);
dy(202,:) = P.k4_2f(8).*y(93,:).*y(63,:) - P.k4_2r(8).*y(202,:) - P.kcat4(8).*y(202,:);
dy(217,:) = P.k4_2f(9).*y(93,:).*y(73,:) - P.k4_2r(9).*y(217,:) - P.kcat4(9).*y(217,:);

% FabG-NADPH-(C2n:1 (n=6:10) B-ketoacyl-ACPs)
dy(226,:) = P.k4_2f(5).*y(93,:).*y(38,:) - P.k4_2r(5).*y(226,:) - P.kcat4(5).*y(226,:);
dy(241,:) = P.k4_2f(6).*y(93,:).*y(48,:) - P.k4_2r(6).*y(241,:) - P.kcat4(6).*y(241,:);
dy(256,:) = P.k4_2f(7).*y(93,:).*y(58,:) - P.k4_2r(7).*y(256,:) - P.kcat4(7).*y(256,:);
dy(271,:) = P.k4_2f(8).*y(93,:).*y(68,:) - P.k4_2r(8).*y(271,:) - P.kcat4(8).*y(271,:);
dy(286,:) = P.k4_2f(9).*y(93,:).*y(78,:) - P.k4_2r(9).*y(286,:) - P.kcat4(9).*y(286,:);

% FabZ-(C2n (n=2:10) B-hydroxyacyl-ACPs)
dy(98,:)  = P.k5_1f(1).*e5.*y(13,:) - P.k5_1r(1).*y(98,:) - P.kcat5(1).*y(98,:) + P.k5_2r(1).*y(99,:);
dy(113,:) = P.k5_1f(2).*e5.*y(18,:) - P.k5_1r(2).*y(113,:) - P.kcat5(2).*y(113,:) + P.k5_2r(2).*y(114,:);
dy(128,:) = P.k5_1f(3).*e5.*y(23,:) - P.k5_1r(3).*y(128,:) - P.kcat5(3).*y(128,:) + P.k5_2r(3).*y(129,:);
dy(143,:) = P.k5_1f(4).*e5.*y(28,:) - P.k5_1r(4).*y(143,:) - P.kcat5(4).*y(143,:) + P.k5_2r(4).*y(144,:);
dy(158,:) = P.k5_1f(5).*e5.*y(34,:) - P.k5_1r(5).*y(158,:) - P.kcat5(5).*y(158,:) + P.k5_2r(5).*y(159,:);
dy(173,:) = P.k5_1f(6).*e5.*y(44,:) - P.k5_1r(6).*y(173,:) - P.kcat5(6).*y(173,:) + P.k5_2r(6).*y(174,:);
dy(188,:) = P.k5_1f(7).*e5.*y(54,:) - P.k5_1r(7).*y(188,:) - P.kcat5(7).*y(188,:) + P.k5_2r(7).*y(189,:);
dy(203,:) = P.k5_1f(8).*e5.*y(64,:) - P.k5_1r(8).*y(203,:) - P.kcat5(8).*y(203,:) + P.k5_2r(8).*y(204,:);
dy(218,:) = P.k5_1f(9).*e5.*y(74,:) - P.k5_1r(9).*y(218,:) - P.kcat5(9).*y(218,:) + P.k5_2r(9).*y(219,:);

% FabZ-(C2n:1 (n=6:10) B-hydroxyacyl-ACPs)
dy(227,:) = P.k5_1f(5).*e5.*y(39,:) - P.k5_1r(5).*y(227,:) - P.kcat5(5).*y(227,:) + P.k5_2r(5).*y(228,:);
dy(242,:) = P.k5_1f(6).*e5.*y(49,:) - P.k5_1r(6).*y(242,:) - P.kcat5(6).*y(242,:) + P.k5_2r(6).*y(243,:);
dy(257,:) = P.k5_1f(7).*e5.*y(59,:) - P.k5_1r(7).*y(257,:) - P.kcat5(7).*y(257,:) + P.k5_2r(7).*y(258,:);
dy(272,:) = P.k5_1f(8).*e5.*y(69,:) - P.k5_1r(8).*y(272,:) - P.kcat5(8).*y(272,:) + P.k5_2r(8).*y(273,:);
dy(287,:) = P.k5_1f(9).*e5.*y(79,:) - P.k5_1r(9).*y(287,:) - P.kcat5(9).*y(287,:) + P.k5_2r(9).*y(288,:);

% FabZ-(C2n (n=2:10) Enoyl-Acyl-ACPs)
dy(99,:) = P.kcat5(1).*y(98,:) - P.k5_2r(1).*y(99,:) - P.k5_3f(1).*y(99,:) + P.k5_3r(1).*e5.*y(14,:);
dy(114,:) = P.kcat5(2).*y(113,:) - P.k5_2r(2).*y(114,:) - P.k5_3f(2).*y(114,:) + P.k5_3r(2).*e5.*y(19,:);
dy(129,:) = P.kcat5(3).*y(128,:) - P.k5_2r(3).*y(129,:) - P.k5_3f(3).*y(129,:) + P.k5_3r(3).*e5.*y(24,:);
dy(144,:) = P.kcat5(4).*y(143,:) - P.k5_2r(4).*y(144,:) - P.k5_3f(4).*y(144,:) + P.k5_3r(4).*e5.*y(29,:);
dy(159,:) = P.kcat5(5).*y(158,:) - P.k5_2r(5).*y(159,:) - P.k5_3f(5).*y(159,:) + P.k5_3r(5).*e5.*y(35,:);
dy(174,:) = P.kcat5(6).*y(173,:) - P.k5_2r(6).*y(174,:) - P.k5_3f(6).*y(174,:) + P.k5_3r(6).*e5.*y(45,:);
dy(189,:) = P.kcat5(7).*y(188,:) - P.k5_2r(7).*y(189,:) - P.k5_3f(7).*y(189,:) + P.k5_3r(7).*e5.*y(55,:);
dy(204,:) = P.kcat5(8).*y(203,:) - P.k5_2r(8).*y(204,:) - P.k5_3f(8).*y(204,:) + P.k5_3r(8).*e5.*y(65,:);
dy(219,:) = P.kcat5(9).*y(218,:) - P.k5_2r(9).*y(219,:) - P.k5_3f(9).*y(219,:) + P.k5_3r(9).*e5.*y(75,:);

% FabZ-(C2n:1 (n=6:10) Enoyl-Acyl-ACPs)
dy(228,:) = P.kcat5(5).*y(227,:) - P.k5_2r(5).*y(228,:) - P.k5_3f(5).*y(228,:) + P.k5_3r(5).*e5.*y(40,:);
dy(243,:) = P.kcat5(6).*y(242,:) - P.k5_2r(6).*y(243,:) - P.k5_3f(6).*y(243,:) + P.k5_3r(6).*e5.*y(50,:);
dy(258,:) = P.kcat5(7).*y(257,:) - P.k5_2r(7).*y(258,:) - P.k5_3f(7).*y(258,:) + P.k5_3r(7).*e5.*y(60,:);
dy(273,:) = P.kcat5(8).*y(272,:) - P.k5_2r(8).*y(273,:) - P.k5_3f(8).*y(273,:) + P.k5_3r(8).*e5.*y(70,:);
dy(288,:) = P.kcat5(9).*y(287,:) - P.k5_2r(9).*y(288,:) - P.k5_3f(9).*y(288,:) + P.k5_3r(9).*e5.*y(80,:);

% FabA-(C2n (n=2:10) B-hydroxyacyl-ACPs)
dy(105,:) = P.k9_1f(1).*e9.*y(13,:) - P.k9_1r(1).*y(105,:) - P.kcat9(1).*y(105,:) + P.k9_2r(1).*y(106,:);
dy(120,:) = P.k9_1f(2).*e9.*y(18,:) - P.k9_1r(2).*y(120,:) - P.kcat9(2).*y(120,:) + P.k9_2r(2).*y(121,:);
dy(135,:) = P.k9_1f(3).*e9.*y(23,:) - P.k9_1r(3).*y(135,:) - P.kcat9(3).*y(135,:) + P.k9_2r(3).*y(136,:);
dy(150,:) = P.k9_1f(4).*e9.*y(28,:) - P.k9_1r(4).*y(150,:) - P.kcat9(4).*y(150,:) + P.k9_2r(4).*y(151,:);
dy(165,:) = P.k9_1f(5).*e9.*y(34,:) - P.k9_1r(5).*y(165,:) - P.kcat9(5).*y(165,:) + P.k9_2r(5).*y(166,:);
dy(180,:) = P.k9_1f(6).*e9.*y(44,:) - P.k9_1r(6).*y(180,:) - P.kcat9(6).*y(180,:) + P.k9_2r(6).*y(181,:);
dy(195,:) = P.k9_1f(7).*e9.*y(54,:) - P.k9_1r(7).*y(195,:) - P.kcat9(7).*y(195,:) + P.k9_2r(7).*y(196,:);
dy(210,:) = P.k9_1f(8).*e9.*y(64,:) - P.k9_1r(8).*y(210,:) - P.kcat9(8).*y(210,:) + P.k9_2r(8).*y(211,:);
dy(222,:) = P.k9_1f(9).*e9.*y(74,:) - P.k9_1r(9).*y(222,:) - P.kcat9(9).*y(222,:) + P.k9_2r(9).*y(223,:);

% FabA-(C2n:1 (n=6:10) B-hydroxyacyl-ACPs)
dy(234,:) = P.k9_1f_un(5).*e9.*y(39,:) - P.k9_1r_un(5).*y(234,:) - P.kcat9(5).*y(234,:) + P.k9_2r(5).*y(235,:);
dy(249,:) = P.k9_1f_un(6).*e9.*y(49,:) - P.k9_1r_un(6).*y(249,:) - P.kcat9(6).*y(249,:) + P.k9_2r(6).*y(250,:);
dy(264,:) = P.k9_1f_un(7).*e9.*y(59,:) - P.k9_1r_un(7).*y(264,:) - P.kcat9(7).*y(264,:) + P.k9_2r(7).*y(265,:);
dy(279,:) = P.k9_1f_un(8).*e9.*y(69,:) - P.k9_1r_un(8).*y(279,:) - P.kcat9(8).*y(279,:) + P.k9_2r(8).*y(280,:);
dy(291,:) = P.k9_1f_un(9).*e9.*y(79,:) - P.k9_1r_un(9).*y(291,:) - P.kcat9(9).*y(291,:) + P.k9_2r(9).*y(292,:);

% FabA-(C2n (n=2:10) Enoyl-Acyl-ACPs)
dy(106,:) = P.kcat9(1).*y(105,:) - P.k9_2r(1).*y(106,:) - P.k9_3f(1).*y(106,:) + P.k9_3r(1).*e9.*y(14,:);
dy(121,:) = P.kcat9(2).*y(120,:) - P.k9_2r(2).*y(121,:) - P.k9_3f(2).*y(121,:) + P.k9_3r(2).*e9.*y(19,:);
dy(136,:) = P.kcat9(3).*y(135,:) - P.k9_2r(3).*y(136,:) - P.k9_3f(3).*y(136,:) + P.k9_3r(3).*e9.*y(24,:);
dy(151,:) = P.kcat9(4).*y(150,:) - P.k9_2r(4).*y(151,:) - P.k9_3f(4).*y(151,:) + P.k9_3r(4).*e9.*y(29,:) - P.kcat9_un(4).*y(151,:) + P.k9_2r_un(4).*y(301,:);
dy(166,:) = P.kcat9(5).*y(165,:) - P.k9_2r(5).*y(166,:) - P.k9_3f(5).*y(166,:) + P.k9_3r(5).*e9.*y(35,:);
dy(181,:) = P.kcat9(6).*y(180,:) - P.k9_2r(6).*y(181,:) - P.k9_3f(6).*y(181,:) + P.k9_3r(6).*e9.*y(45,:);
dy(196,:) = P.kcat9(7).*y(195,:) - P.k9_2r(7).*y(196,:) - P.k9_3f(7).*y(196,:) + P.k9_3r(7).*e9.*y(55,:);
dy(211,:) = P.kcat9(8).*y(210,:) - P.k9_2r(8).*y(211,:) - P.k9_3f(8).*y(211,:) + P.k9_3r(8).*e9.*y(65,:);
dy(223,:) = P.kcat9(9).*y(222,:) - P.k9_2r(9).*y(223,:) - P.k9_3f(9).*y(223,:) + P.k9_3r(9).*e9.*y(75,:);

% FabA-C10 cis-3-Enoyl-Acyl-ACP
dy(301,:) = P.kcat9_un(4).*y(151,:) - P.k9_2r_un(4).*y(301,:) - P.k9_3f_un(4).*y(301,:) + P.k9_3r_un(4).*e9.*y(32,:);

% FabA-(C2n:1 (n=6:10) Enoyl-Acyl-ACPs)
dy(235,:) = P.kcat9(5).*y(234,:) - P.k9_2r(5).*y(235,:) - P.k9_3f(5).*y(235,:) + P.k9_3r(5).*e9.*y(40,:);
dy(250,:) = P.kcat9(6).*y(249,:) - P.k9_2r(6).*y(250,:) - P.k9_3f(6).*y(250,:) + P.k9_3r(6).*e9.*y(50,:);
dy(265,:) = P.kcat9(7).*y(264,:) - P.k9_2r(7).*y(265,:) - P.k9_3f(7).*y(265,:) + P.k9_3r(7).*e9.*y(60,:);
dy(280,:) = P.kcat9(8).*y(279,:) - P.k9_2r(8).*y(280,:) - P.k9_3f(8).*y(280,:) + P.k9_3r(8).*e9.*y(70,:);
dy(292,:) = P.kcat9(9).*y(291,:) - P.k9_2r(9).*y(292,:) - P.k9_3f(9).*y(292,:) + P.k9_3r(9).*e9.*y(80,:);

% FabI-NADH
dy(94,:) = P.k6_1f(1).*e6.*y(6,:) - P.k6_1r(1).*y(94,:)...
 + P.k6_2r(1).*y(100,:) - P.k6_2f(1).*y(94,:).*y(14,:)...
 + P.k6_2r(2).*y(115,:) - P.k6_2f(2).*y(94,:).*y(19,:)...
 + P.k6_2r(3).*y(130,:) - P.k6_2f(3).*y(94,:).*y(24,:)...
 + P.k6_2r(4).*y(145,:) - P.k6_2f(4).*y(94,:).*y(29,:)...
 + P.k6_2r(5).*y(160,:) - P.k6_2f(5).*y(94,:).*y(35,:)...
 + P.k6_2r(6).*y(175,:) - P.k6_2f(6).*y(94,:).*y(45,:)...
 + P.k6_2r(7).*y(190,:) - P.k6_2f(7).*y(94,:).*y(55,:)...
 + P.k6_2r(8).*y(205,:) - P.k6_2f(8).*y(94,:).*y(65,:)...
 + P.k6_2r(9).*y(220,:) - P.k6_2f(9).*y(94,:).*y(75,:)...
 + P.k6_2r(5).*y(229,:) - P.k6_2f(5).*y(94,:).*y(40,:)...
 + P.k6_2r(6).*y(244,:) - P.k6_2f(6).*y(94,:).*y(50,:)...
 + P.k6_2r(7).*y(259,:) - P.k6_2f(7).*y(94,:).*y(60,:)...
 + P.k6_2r(8).*y(274,:) - P.k6_2f(8).*y(94,:).*y(70,:)...
 + P.k6_2r(9).*y(289,:) - P.k6_2f(9).*y(94,:).*y(80,:);

% FabI-NADH-(C2n (n=2:10) Enoyl-Acyl-ACPs)
dy(100,:) = P.k6_2f(1).*y(94,:).*y(14,:) - P.k6_2r(1).*y(100,:) - P.kcat6(1).*y(100,:);
dy(115,:) = P.k6_2f(2).*y(94,:).*y(19,:) - P.k6_2r(2).*y(115,:) - P.kcat6(2).*y(115,:);
dy(130,:) = P.k6_2f(3).*y(94,:).*y(24,:) - P.k6_2r(3).*y(130,:) - P.kcat6(3).*y(130,:);
dy(145,:) = P.k6_2f(4).*y(94,:).*y(29,:) - P.k6_2r(4).*y(145,:) - P.kcat6(4).*y(145,:);
dy(160,:) = P.k6_2f(5).*y(94,:).*y(35,:) - P.k6_2r(5).*y(160,:) - P.kcat6(5).*y(160,:);
dy(175,:) = P.k6_2f(6).*y(94,:).*y(45,:) - P.k6_2r(6).*y(175,:) - P.kcat6(6).*y(175,:);
dy(190,:) = P.k6_2f(7).*y(94,:).*y(55,:) - P.k6_2r(7).*y(190,:) - P.kcat6(7).*y(190,:);
dy(205,:) = P.k6_2f(8).*y(94,:).*y(65,:) - P.k6_2r(8).*y(205,:) - P.kcat6(8).*y(205,:);
dy(220,:) = P.k6_2f(9).*y(94,:).*y(75,:) - P.k6_2r(9).*y(220,:) - P.kcat6(9).*y(220,:);

% FabI-NADH-(C2n:1 (n=6:10) Enoyl-Acyl-ACPs)
dy(229,:) = P.k6_2f(5).*y(94,:).*y(40,:) - P.k6_2r(5).*y(229,:) - P.kcat6(5).*y(229,:);
dy(244,:) = P.k6_2f(6).*y(94,:).*y(50,:) - P.k6_2r(6).*y(244,:) - P.kcat6(6).*y(244,:);
dy(259,:) = P.k6_2f(7).*y(94,:).*y(60,:) - P.k6_2r(7).*y(259,:) - P.kcat6(7).*y(259,:);
dy(274,:) = P.k6_2f(8).*y(94,:).*y(70,:) - P.k6_2r(8).*y(274,:) - P.kcat6(8).*y(274,:);
dy(289,:) = P.k6_2f(9).*y(94,:).*y(80,:) - P.k6_2r(9).*y(289,:) - P.kcat6(9).*y(289,:);

% TesA-(C2n (n=2:10) Acyl-ACPs)
dy(101,:) = P.k7_1f(1).*e7.*y(15,:) - P.k7_1r(1).*y(101,:) - P.kcat7(1).*y(101,:);
dy(116,:) = P.k7_1f(2).*e7.*y(20,:) - P.k7_1r(2).*y(116,:) - P.kcat7(2).*y(116,:);
dy(131,:) = P.k7_1f(3).*e7.*y(25,:) - P.k7_1r(3).*y(131,:) - P.kcat7(3).*y(131,:);
dy(146,:) = P.k7_1f(4).*e7.*y(30,:) - P.k7_1r(4).*y(146,:) - P.kcat7(4).*y(146,:);
dy(161,:) = P.k7_1f(5).*e7.*y(36,:) - P.k7_1r(5).*y(161,:) - P.kcat7(5).*y(161,:);
dy(176,:) = P.k7_1f(6).*e7.*y(46,:) - P.k7_1r(6).*y(176,:) - P.kcat7(6).*y(176,:);
dy(191,:) = P.k7_1f(7).*e7.*y(56,:) - P.k7_1r(7).*y(191,:) - P.kcat7(7).*y(191,:);
dy(206,:) = P.k7_1f(8).*e7.*y(66,:) - P.k7_1r(8).*y(206,:) - P.kcat7(8).*y(206,:);
dy(221,:) = P.k7_1f(9).*e7.*y(76,:) - P.k7_1r(9).*y(221,:) - P.kcat7(9).*y(221,:);

% TesA-(C2n:1 (n=6:10) Acyl-ACPs)
dy(230,:) = P.k7_1f(5).*e7.*y(41,:) - P.k7_1r(5).*y(230,:) - P.kcat7(5).*y(230,:);
dy(245,:) = P.k7_1f(6).*e7.*y(51,:) - P.k7_1r(6).*y(245,:) - P.kcat7(6).*y(245,:);
dy(260,:) = P.k7_1f(7).*e7.*y(61,:) - P.k7_1r(7).*y(260,:) - P.kcat7(7).*y(260,:);
dy(275,:) = P.k7_1f(8).*e7.*y(71,:) - P.k7_1r(8).*y(275,:) - P.kcat7(8).*y(275,:);
dy(290,:) = P.k7_1f(9).*e7.*y(81,:) - P.k7_1r(9).*y(290,:) - P.kcat7(9).*y(290,:);

% FabF-(C2n (n=2:9) Acyl-ACPs)
dy(102,:) = P.k8_1f(1).*e8.*y(15,:) + P.k8_2r(1).*y(103,:).*y(4,:) - P.k8_1r(1).*y(102,:) - P.k8_2f(1).*y(102,:);
dy(117,:) = P.k8_1f(2).*e8.*y(20,:) + P.k8_2r(2).*y(118,:).*y(4,:) - P.k8_1r(2).*y(117,:) - P.k8_2f(2).*y(117,:);
dy(132,:) = P.k8_1f(3).*e8.*y(25,:) + P.k8_2r(3).*y(133,:).*y(4,:) - P.k8_1r(3).*y(132,:) - P.k8_2f(3).*y(132,:);
dy(147,:) = P.k8_1f(4).*e8.*y(30,:) + P.k8_2r(4).*y(148,:).*y(4,:) - P.k8_1r(4).*y(147,:) - P.k8_2f(4).*y(147,:);
dy(162,:) = P.k8_1f(5).*e8.*y(36,:) + P.k8_2r(5).*y(163,:).*y(4,:) - P.k8_1r(5).*y(162,:) - P.k8_2f(5).*y(162,:);
dy(177,:) = P.k8_1f(6).*e8.*y(46,:) + P.k8_2r(6).*y(178,:).*y(4,:) - P.k8_1r(6).*y(177,:) - P.k8_2f(6).*y(177,:);
dy(192,:) = P.k8_1f(7).*e8.*y(56,:) + P.k8_2r(7).*y(193,:).*y(4,:) - P.k8_1r(7).*y(192,:) - P.k8_2f(7).*y(192,:);
dy(207,:) = P.k8_1f(8).*e8.*y(66,:) + P.k8_2r(8).*y(208,:).*y(4,:) - P.k8_1r(8).*y(207,:) - P.k8_2f(8).*y(207,:);

% FabF-(C2n:1 (n=6:9) Acyl-ACPs)
dy(231,:) = P.k8_1f(5).*e8.*y(41,:) + P.k8_2r(5).*y(232,:).*y(4,:) - P.k8_1r(5).*y(231,:) - P.k8_2f(5).*y(231,:);
dy(246,:) = P.k8_1f(6).*e8.*y(51,:) + P.k8_2r(6).*y(247,:).*y(4,:) - P.k8_1r(6).*y(246,:) - P.k8_2f(6).*y(246,:);
dy(261,:) = P.k8_1f(7).*e8.*y(61,:) + P.k8_2r(7).*y(262,:).*y(4,:) - P.k8_1r(7).*y(261,:) - P.k8_2f(7).*y(261,:);
dy(276,:) = P.k8_1f(8).*e8.*y(71,:) + P.k8_2r(8).*y(277,:).*y(4,:) - P.k8_1r(8).*y(276,:) - P.k8_2f(8).*y(276,:);

% C2n (n=2:9) FabF*
dy(103,:) = P.k8_2f(1).*y(102,:) + P.k8_3r(1).*y(104,:) - P.k8_2r(1).*y(103,:).*y(4,:) - P.k8_3f(1).*y(103,:).*y(10,:);
dy(118,:) = P.k8_2f(2).*y(117,:) + P.k8_3r(2).*y(119,:) - P.k8_2r(2).*y(118,:).*y(4,:) - P.k8_3f(2).*y(118,:).*y(10,:);
dy(133,:) = P.k8_2f(3).*y(132,:) + P.k8_3r(3).*y(134,:) - P.k8_2r(3).*y(133,:).*y(4,:) - P.k8_3f(3).*y(133,:).*y(10,:);
dy(148,:) = P.k8_2f(4).*y(147,:) + P.k8_3r(4).*y(149,:) - P.k8_2r(4).*y(148,:).*y(4,:) - P.k8_3f(4).*y(148,:).*y(10,:);
dy(163,:) = P.k8_2f(5).*y(162,:) + P.k8_3r(5).*y(164,:) - P.k8_2r(5).*y(163,:).*y(4,:) - P.k8_3f(5).*y(163,:).*y(10,:);
dy(178,:) = P.k8_2f(6).*y(177,:) + P.k8_3r(6).*y(179,:) - P.k8_2r(6).*y(178,:).*y(4,:) - P.k8_3f(6).*y(178,:).*y(10,:);
dy(193,:) = P.k8_2f(7).*y(192,:) + P.k8_3r(7).*y(194,:) - P.k8_2r(7).*y(193,:).*y(4,:) - P.k8_3f(7).*y(193,:).*y(10,:);
dy(208,:) = P.k8_2f(8).*y(207,:) + P.k8_3r(8).*y(209,:) - P.k8_2r(8).*y(208,:).*y(4,:) - P.k8_3f(8).*y(208,:).*y(10,:);

% C2n:1 (n=6:9) FabF*
dy(232,:) = P.k8_2f(5).*y(231,:) + P.k8_3r(5).*y(233,:) - P.k8_2r(5).*y(232,:).*y(4,:) - P.k8_3f(5).*y(232,:).*y(10,:);
dy(247,:) = P.k8_2f(6).*y(246,:) + P.k8_3r(6).*y(248,:) - P.k8_2r(6).*y(247,:).*y(4,:) - P.k8_3f(6).*y(247,:).*y(10,:);
dy(262,:) = P.k8_2f(7).*y(261,:) + P.k8_3r(7).*y(263,:) - P.k8_2r(7).*y(262,:).*y(4,:) - P.k8_3f(7).*y(262,:).*y(10,:);
dy(277,:) = P.k8_2f(8).*y(276,:) + P.k8_3r(8).*y(278,:) - P.k8_2r(8).*y(277,:).*y(4,:) - P.k8_3f(8).*y(277,:).*y(10,:);

% C2n (n=2:9) FabF*-Malonyl-ACPs
dy(104,:) = P.k8_3f(1).*y(103,:).*y(10,:) - P.k8_3r(1).*y(104,:) - P.kcat8(1).*y(104,:);
dy(119,:) = P.k8_3f(2).*y(118,:).*y(10,:) - P.k8_3r(2).*y(119,:) - P.kcat8(2).*y(119,:);
dy(134,:) = P.k8_3f(3).*y(133,:).*y(10,:) - P.k8_3r(3).*y(134,:) - P.kcat8(3).*y(134,:);
dy(149,:) = P.k8_3f(4).*y(148,:).*y(10,:) - P.k8_3r(4).*y(149,:) - P.kcat8(4).*y(149,:);
dy(164,:) = P.k8_3f(5).*y(163,:).*y(10,:) - P.k8_3r(5).*y(164,:) - P.kcat8(5).*y(164,:);
dy(179,:) = P.k8_3f(6).*y(178,:).*y(10,:) - P.k8_3r(6).*y(179,:) - P.kcat8(6).*y(179,:);
dy(194,:) = P.k8_3f(7).*y(193,:).*y(10,:) - P.k8_3r(7).*y(194,:) - P.kcat8(7).*y(194,:);
dy(209,:) = P.k8_3f(8).*y(208,:).*y(10,:) - P.k8_3r(8).*y(209,:) - P.kcat8(8).*y(209,:);

% C2n:1 (n=6:9) FabF*-Malonyl-ACPs
dy(233,:) = P.k8_3f(5).*y(232,:).*y(10,:) - P.k8_3r(5).*y(233,:) - P.kcat8_un(5).*y(233,:);
dy(248,:) = P.k8_3f(6).*y(247,:).*y(10,:) - P.k8_3r(6).*y(248,:) - P.kcat8_un(6).*y(248,:);
dy(263,:) = P.k8_3f(7).*y(262,:).*y(10,:) - P.k8_3r(7).*y(263,:) - P.kcat8_un(7).*y(263,:);
dy(278,:) = P.k8_3f(8).*y(277,:).*y(10,:) - P.k8_3r(8).*y(278,:) - P.kcat8_un(8).*y(278,:);

% FabB-(C2n (n=2:9) Acyl-ACPs)
dy(107,:) = P.k10_1f(1).*e10.*y(15,:) + P.k10_2r(1).*y(108,:).*y(4,:) - P.k10_1r(1).*y(107,:) - P.k10_2f(1).*y(107,:);
dy(122,:) = P.k10_1f(2).*e10.*y(20,:) + P.k10_2r(2).*y(123,:).*y(4,:) - P.k10_1r(2).*y(122,:) - P.k10_2f(2).*y(122,:);
dy(137,:) = P.k10_1f(3).*e10.*y(25,:) + P.k10_2r(3).*y(138,:).*y(4,:) - P.k10_1r(3).*y(137,:) - P.k10_2f(3).*y(137,:);
dy(152,:) = P.k10_1f(4).*e10.*y(30,:) + P.k10_2r(4).*y(153,:).*y(4,:) - P.k10_1r(4).*y(152,:) - P.k10_2f(4).*y(152,:);
dy(167,:) = P.k10_1f(5).*e10.*y(36,:) + P.k10_2r(5).*y(168,:).*y(4,:) - P.k10_1r(5).*y(167,:) - P.k10_2f(5).*y(167,:);
dy(182,:) = P.k10_1f(6).*e10.*y(46,:) + P.k10_2r(6).*y(183,:).*y(4,:) - P.k10_1r(6).*y(182,:) - P.k10_2f(6).*y(182,:);
dy(197,:) = P.k10_1f(7).*e10.*y(56,:) + P.k10_2r(7).*y(198,:).*y(4,:) - P.k10_1r(7).*y(197,:) - P.k10_2f(7).*y(197,:);
dy(212,:) = P.k10_1f(8).*e10.*y(66,:) + P.k10_2r(8).*y(213,:).*y(4,:) - P.k10_1r(8).*y(212,:) - P.k10_2f(8).*y(212,:);

% FabB-(C2n:1 (n=6:9) Acyl-ACPs)
dy(236,:) = P.k10_1f(5).*e10.*y(41,:) + P.k10_2r(5).*y(237,:).*y(4,:) - P.k10_1r(5).*y(236,:) - P.k10_2f(5).*y(236,:);
dy(251,:) = P.k10_1f(6).*e10.*y(51,:) + P.k10_2r(6).*y(252,:).*y(4,:) - P.k10_1r(6).*y(251,:) - P.k10_2f(6).*y(251,:);
dy(266,:) = P.k10_1f(7).*e10.*y(61,:) + P.k10_2r(7).*y(267,:).*y(4,:) - P.k10_1r(7).*y(266,:) - P.k10_2f(7).*y(266,:);
dy(281,:) = P.k10_1f(8).*e10.*y(71,:) + P.k10_2r(8).*y(282,:).*y(4,:) - P.k10_1r(8).*y(281,:) - P.k10_2f(8).*y(281,:);

% C2n (n=2:9) FabB*
dy(108,:) = P.k10_2f(1).*y(107,:) + P.k10_3r(1).*y(109,:) - P.k10_2r(1).*y(108,:).*y(4,:) - P.k10_3f(1).*y(108,:).*y(10,:);
dy(123,:) = P.k10_2f(2).*y(122,:) + P.k10_3r(2).*y(124,:) - P.k10_2r(2).*y(123,:).*y(4,:) - P.k10_3f(2).*y(123,:).*y(10,:);
dy(138,:) = P.k10_2f(3).*y(137,:) + P.k10_3r(3).*y(139,:) - P.k10_2r(3).*y(138,:).*y(4,:) - P.k10_3f(3).*y(138,:).*y(10,:);
dy(153,:) = P.k10_2f(4).*y(152,:) + P.k10_3r(4).*y(154,:) - P.k10_2r(4).*y(153,:).*y(4,:) - P.k10_3f(4).*y(153,:).*y(10,:);
dy(168,:) = P.k10_2f(5).*y(167,:) + P.k10_3r(5).*y(169,:) - P.k10_2r(5).*y(168,:).*y(4,:) - P.k10_3f(5).*y(168,:).*y(10,:);
dy(183,:) = P.k10_2f(6).*y(182,:) + P.k10_3r(6).*y(184,:) - P.k10_2r(6).*y(183,:).*y(4,:) - P.k10_3f(6).*y(183,:).*y(10,:);
dy(198,:) = P.k10_2f(7).*y(197,:) + P.k10_3r(7).*y(199,:) - P.k10_2r(7).*y(198,:).*y(4,:) - P.k10_3f(7).*y(198,:).*y(10,:);
dy(213,:) = P.k10_2f(8).*y(212,:) + P.k10_3r(8).*y(214,:) - P.k10_2r(8).*y(213,:).*y(4,:) - P.k10_3f(8).*y(213,:).*y(10,:);

% C2n:1 (n=6:9) FabB*
dy(237,:) = P.k10_2f(5).*y(236,:) + P.k10_3r(5).*y(238,:) - P.k10_2r(5).*y(237,:).*y(4,:) - P.k10_3f(5).*y(237,:).*y(10,:);
dy(252,:) = P.k10_2f(6).*y(251,:) + P.k10_3r(6).*y(253,:) - P.k10_2r(6).*y(252,:).*y(4,:) - P.k10_3f(6).*y(252,:).*y(10,:);
dy(267,:) = P.k10_2f(7).*y(266,:) + P.k10_3r(7).*y(268,:) - P.k10_2r(7).*y(267,:).*y(4,:) - P.k10_3f(7).*y(267,:).*y(10,:);
dy(282,:) = P.k10_2f(8).*y(281,:) + P.k10_3r(8).*y(283,:) - P.k10_2r(8).*y(282,:).*y(4,:) - P.k10_3f(8).*y(282,:).*y(10,:);

% C2n (n=2:9) FabB*-Malonyl-ACPs
dy(109,:) = P.k10_3f(1).*y(108,:).*y(10,:) - P.k10_3r(1).*y(109,:) - P.kcat10(1).*y(109,:);
dy(124,:) = P.k10_3f(2).*y(123,:).*y(10,:) - P.k10_3r(2).*y(124,:) - P.kcat10(2).*y(124,:);
dy(139,:) = P.k10_3f(3).*y(138,:).*y(10,:) - P.k10_3r(3).*y(139,:) - P.kcat10(3).*y(139,:);
dy(154,:) = P.k10_3f(4).*y(153,:).*y(10,:) - P.k10_3r(4).*y(154,:) - P.kcat10(4).*y(154,:);
dy(169,:) = P.k10_3f(5).*y(168,:).*y(10,:) - P.k10_3r(5).*y(169,:) - P.kcat10(5).*y(169,:);
dy(184,:) = P.k10_3f(6).*y(183,:).*y(10,:) - P.k10_3r(6).*y(184,:) - P.kcat10(6).*y(184,:);
dy(199,:) = P.k10_3f(7).*y(198,:).*y(10,:) - P.k10_3r(7).*y(199,:) - P.kcat10(7).*y(199,:);
dy(214,:) = P.k10_3f(8).*y(213,:).*y(10,:) - P.k10_3r(8).*y(214,:) - P.kcat10(8).*y(214,:);

% C2n:1 (n=6:9) FabB*-Malonyl-ACPs
dy(238,:) = P.k10_3f(5).*y(237,:).*y(10,:) - P.k10_3r(5).*y(238,:) - P.kcat10_un(5).*y(238,:);
dy(253,:) = P.k10_3f(6).*y(252,:).*y(10,:) - P.k10_3r(6).*y(253,:) - P.kcat10_un(6).*y(253,:);
dy(268,:) = P.k10_3f(7).*y(267,:).*y(10,:) - P.k10_3r(7).*y(268,:) - P.kcat10_un(7).*y(268,:);
dy(283,:) = P.k10_3f(8).*y(282,:).*y(10,:) - P.k10_3r(8).*y(283,:) - P.kcat10_un(8).*y(283,:);

% FabB-(C10 cis-3-Enoyl-Acyl-ACP)
dy(302,:) = P.k10_1f(4).*e10.*y(32,:) + P.k10_2r(4).*y(303,:).*y(4,:) - P.k10_1r(4).*y(302,:) - P.k10_2f(4).*y(302,:);

% C10 cis-3-FabB*
dy(303,:) = P.k10_2f(4).*y(302,:) + P.k10_3r(4).*y(304,:) - P.k10_2r(4).*y(303,:).*y(4,:) - P.k10_3f(4).*y(303,:).*y(10,:);

% C10 cis-3-FabB*-Malonyl-ACP
dy(304,:) = P.k10_3f(4).*y(303,:).*y(10,:) - P.k10_3r(4).*y(304,:) - P.kcat10_un(4).*y(304,:);

% FabH-(C2n (n=2:10) Acyl-ACPs)
dy(95,:) = P.k3_4f(1).*e3.*y(15,:) - P.k3_4r(1).*y(95,:);
dy(110,:) = P.k3_4f(2).*e3.*y(20,:) - P.k3_4r(2).*y(110,:);
dy(125,:) = P.k3_4f(3).*e3.*y(25,:) - P.k3_4r(3).*y(125,:);
dy(140,:) = P.k3_4f(4).*e3.*y(30,:) - P.k3_4r(4).*y(140,:);
dy(155,:) = P.k3_4f(5).*e3.*y(36,:) - P.k3_4r(5).*y(155,:);
dy(170,:) = P.k3_4f(6).*e3.*y(46,:) - P.k3_4r(6).*y(170,:);
dy(185,:) = P.k3_4f(7).*e3.*y(56,:) - P.k3_4r(7).*y(185,:);
dy(200,:) = P.k3_4f(8).*e3.*y(66,:) - P.k3_4r(8).*y(200,:);
dy(215,:) = P.k3_4f(9).*e3.*y(76,:) - P.k3_4r(9).*y(215,:);

% FabH-(C2n:1 (n=6:10) Acyl-ACPs)
dy(224,:) = P.k3_4f(5).*e3.*y(41,:) - P.k3_4r(5).*y(224,:);
dy(239,:) = P.k3_4f(6).*e3.*y(51,:) - P.k3_4r(6).*y(239,:);
dy(254,:) = P.k3_4f(7).*e3.*y(61,:) - P.k3_4r(7).*y(254,:);
dy(269,:) = P.k3_4f(8).*e3.*y(71,:) - P.k3_4r(8).*y(269,:);
dy(284,:) = P.k3_4f(9).*e3.*y(81,:) - P.k3_4r(9).*y(284,:);

% FabH*-(C2n (n=2:10) Acyl-ACPs)
dy(96,:) = P.k3_5f(1).*y(91,:).*y(15,:) - P.k3_5r(1).*y(96,:);
dy(111,:) = P.k3_5f(2).*y(91,:).*y(20,:) - P.k3_5r(2).*y(111,:);
dy(126,:) = P.k3_5f(3).*y(91,:).*y(25,:) - P.k3_5r(3).*y(126,:);
dy(141,:) = P.k3_5f(4).*y(91,:).*y(30,:) - P.k3_5r(4).*y(141,:);
dy(156,:) = P.k3_5f(5).*y(91,:).*y(36,:) - P.k3_5r(5).*y(156,:);
dy(171,:) = P.k3_5f(6).*y(91,:).*y(46,:) - P.k3_5r(6).*y(171,:);
dy(186,:) = P.k3_5f(7).*y(91,:).*y(56,:) - P.k3_5r(7).*y(186,:);
dy(201,:) = P.k3_5f(8).*y(91,:).*y(66,:) - P.k3_5r(8).*y(201,:);
dy(216,:) = P.k3_5f(9).*y(91,:).*y(76,:) - P.k3_5r(9).*y(216,:);

% FabH*-(C2n:1 (n=6:10) Acyl-ACPs)
dy(225,:) = P.k3_5f(5).*y(91,:).*y(41,:) - P.k3_5r(5).*y(225,:);
dy(240,:) = P.k3_5f(6).*y(91,:).*y(51,:) - P.k3_5r(6).*y(240,:);
dy(255,:) = P.k3_5f(7).*y(91,:).*y(61,:) - P.k3_5r(7).*y(255,:);
dy(270,:) = P.k3_5f(8).*y(91,:).*y(71,:) - P.k3_5r(8).*y(270,:);
dy(285,:) = P.k3_5f(9).*y(91,:).*y(81,:) - P.k3_5r(9).*y(285,:);

% TesA-ACP
dy(297,:) = P.k7_inh_f.*e7.*y(4,:) - P.k7_inh_r.*y(297,:);

% FabH-ACP
dy(293,:) = P.k3_inh_f.*e3.*y(4,:) - P.k3_inh_r.*y(293,:);

% FabG-ACP
dy(294,:) = P.k4_inh_f.*e4.*y(4,:) - P.k4_inh_r.*y(294,:);

% FabZ-ACP
dy(295,:) = P.k5_inh_f.*e5.*y(4,:) - P.k5_inh_r.*y(295,:);

% FabI-ACP
dy(296,:) = P.k6_inh_f.*e6.*y(4,:) - P.k6_inh_r.*y(296,:);

% FabF-ACP
dy(298,:) = P.k8_inh_f.*e8.*y(4,:) - P.k8_inh_r.*y(298,:);

% FabA-ACP
dy(299,:) = P.k9_inh_f.*e9.*y(4,:) - P.k9_inh_r.*y(299,:);

% FabB-ACP
dy(300,:) = P.k10_inh_f.*e10.*y(4,:) - P.k10_inh_r.*y(300,:);


% Giving FabB FabH-like activity
% FabB-Acetyl-CoA
dy(305,:) = P.k10_4f.*e10.*y(3,:) - P.k10_4r.*y(305,:) - P.k10_5f.*y(305,:) + P.k10_5r.*y(306,:).*y(9,:);

% FabB*
dy(306,:) = P.k10_5f.*y(305,:) - P.k10_5r.*y(306,:).*y(9,:) - P.k10_6f.*y(306,:).*y(10,:) + P.k10_6r.*y(307,:) + P.k10_9f.*y(313,:) - P.k10_9r.*y(306,:).*y(4,:);

% FabB*-Malonyl-ACP
dy(307,:) = P.k10_6f.*y(306,:).*y(10,:) - P.k10_6r.*y(307,:) - P.kcat10_H.*y(307,:); 

% Giving FabF FabH-like activity
% FabF-Acetyl-CoA
dy(308,:) = P.k8_4f.*e8.*y(3,:)   - P.k8_4r.*y(308,:)  - P.k8_5f.*y(308,:)  + P.k8_5r.*y(309,:).*y(9,:); 

% FabF*
dy(309,:) = P.k8_5f.*y(308,:)  - P.k8_5r.*y(309,:).*y(9,:)  - P.k8_6f.*y(309,:).*y(10,:)  +  P.k8_6r.*y(310,:) + P.k8_9f.*y(315,:) - P.k8_9r.*y(309,:).*y(4,:); 

% FabF*-Malonyl-ACP
dy(310,:) = P.k8_6f.*y(309,:).*y(10,:)  - P.k8_6r.*y(310,:)  - P.kcat8_H.*y(310,:); 

% FabB and FabF decarboxylating mACP to form aACP and reacting with it to form activated enzyme (initiation)
% FabB-Malonyl-ACP (e10p4)
dy(311,:) = P.k10_7f.*e10.*y(10,:) - P.k10_7r.*y(311,:) - P.kcat10_CO2.*y(311,:);

% Acetyl-ACP (T_2)
dy(312,:) = P.k10_8r.*y(313,:) - P.k10_8f.*e10.*y(312,:) + P.k8_8r.*y(315,:) - P.k8_8f.*e8.*y(312,:); 

% FabB-Acetyl-ACP (e10T_2)
dy(313,:) = P.kcat10_CO2.*y(311,:) + P.k10_8f.*e10.*y(312,:) - P.k10_8r.*y(313,:) - P.k10_9f.*y(313,:) + P.k10_9r.*y(306,:).*y(4,:); 

% FabF-Malonyl-ACP (e8p4)
dy(314,:) = P.k8_7f.*e8.*y(10,:) - P.k8_7r.*y(314,:) - P.kcat8_CO2.*y(314,:); 

% FabF-Acetyl-ACP (e8T_2)
dy(315,:) = P.kcat8_CO2.*y(314,:) + P.k8_8f.*e8.*y(312,:) - P.k8_8r.*y(315,:) - P.k8_9f.*y(315,:) + P.k8_9r.*y(309).*y(4); 

"""

write_to_file(file_name, text)

# %%
import re

# Delete comments
def find_replace_in_file1(input_file, output_file):
    with open(input_file, 'r') as f:
        lines = f.readlines()

    # Filter out lines starting with '%'
    modified_lines = [line for line in lines if not line.startswith('%')]

    with open(output_file, 'w') as f:
        f.writelines(modified_lines)
        
# Change dy(#,:) to Species #:
def find_replace_in_file2(input_file, output_file):
    with open(input_file, 'r') as f:
        content = f.read()

    # Use regular expression to match dy(#,:) pattern
    modified_content = re.sub(r'dy\((\d+),:\)', r'Species #\1:\n', content)

    with open(output_file, 'w') as f:
        f.write(modified_content)
        
# Delete parameters
def find_replace_in_file3(input_file, output_file):
    with open(input_file, 'r') as f:
        content = f.read()

    # Remove substrings starting with P. and ending with .
    modified_content = re.sub(r'P\..*?\.', '', content)

    with open(output_file, 'w') as f:
        f.write(modified_content)

# Replace remaining unessecary characters
def find_replace_in_file4(input_file, output_file, old_str_list, new_str_list):
    with open(input_file, 'r') as f:
        lines = f.readlines()

    with open(output_file, 'w') as f:
        for line in lines:
            for old_str, new_str in zip(old_str_list, new_str_list):
                line = line.replace(old_str, new_str)
            f.write(line)     
        
# Remove extra lines
def find_replace_in_file5(input_file, output_file):
    with open(input_file, 'r') as f:
        lines = f.readlines()

    # Merge lines and remove multiple line breaks
    merged_lines = ' '.join(lines)
    merged_lines = '\n'.join(line.strip() for line in merged_lines.splitlines() if line.strip())

    with open(output_file, 'w') as f:
        f.write(merged_lines)

input_file = "ODE_Function.txt"
output_file = "ODE_Function.txt"

find_replace_in_file1(input_file, output_file)

find_replace_in_file2(input_file, output_file)

find_replace_in_file3(input_file, output_file)

# Check to make sure the enzymes are being replaced correctly
# Make sure e10 is before e1 or it will replace wrong
# Don't include P.e#tot but keep '-' so a new line will occur
old_str_list = ["e10", "e1C", "e1B", "e1AD", "e2", "e3", "e4", "e5", "e6", "e7", "e8", "e9",
                ",:", ".", ";", " ", "(", ")", "-", "+", "*", "=", "y"]

new_str_list = ["(- y(107,:) - y(108,:) - y(109,:) - y(122,:) - y(123,:) - y(124,:) - y(137,:) - y(138,:) - y(139,:) - y(152,:) - y(153,:) - y(154,:) - y(167,:) - y(236,:) - y(168,:) - y(237,:) - y(169,:) - y(238,:) - y(182,:) - y(251,:) - y(183,:) - y(252,:) - y(184,:) - y(253,:) - y(197,:) - y(266,:) - y(198,:) - y(267,:) - y(199,:) - y(268,:) - y(212,:) - y(281,:) - y(213,:) - y(282,:) - y(214,:) - y(283,:) - y(302,:) - y(303,:) - y(304,:) - y(300,:) - y(305,:) - y(306,:) - y(307,:) - y(311,:) - y(313,:))",
                "(- y(83,:) - y(84,:) - y(85,:) - y(319,:))",
                "(- y(319,:) - y(86,:) - y(316,:))",
                "(- y(316,:) - y(317,:) - y(318,:))",
                "(- y(316,:) - y(317,:) - y(318,:))",
                "(- y(90,:) - y(324,:) - y(325,:) - y(326,:) - y(327,:) - y(328,:) - y(329,:) - y(330,:) - y(331,:) - y(91,:) - y(332,:) - y(333,:) - y(334,:) - y(335,:) - y(336,:) - y(337,:) - y(338,:) - y(339,:) - y(92,:) - y(340,:) - y(341,:) - y(342,:) - y(343,:) - y(344,:) - y(345,:) - y(346,:) - y(347,:) - y(95,:) - y(110,:) - y(125,:) - y(140,:) - y(155,:) - y(170,:) - y(185,:) - y(200,:) - y(215,:) - y(224,:) - y(239,:) - y(254,:) - y(269,:) - y(284,:) - y(96,:) - y(111,:) - y(126,:) - y(141,:) - y(156,:) - y(171,:) - y(186,:) - y(201,:) - y(216,:) - y(225,:) - y(240,:) - y(255,:) - y(270,:) - y(285,:) - y(293,:))",
                "(- y(93,:) - y(97,:) - y(112,:) - y(127,:) - y(142,:) - y(157,:) - y(172,:) - y(187,:) - y(202,:) - y(217,:) - y(226,:) - y(241,:) - y(256,:) - y(271,:) - y(286,:) - y(294,:))",
                "(- y(98,:) - y(113,:) - y(128,:) - y(143,:) - y(158,:) - y(173,:) - y(188,:) - y(203,:) - y(218,:) - y(227,:) - y(242,:) - y(257,:) - y(272,:) - y(287,:) - y(99,:) - y(114,:) - y(129,:) - y(144,:) - y(159,:) - y(174,:) - y(189,:) - y(204,:) - y(219,:) - y(228,:) - y(243,:) - y(258,:) - y(273,:) - y(288,:) - y(295,:))",
                "(- y(94,:) - y(100,:) - y(115,:) - y(130,:) - y(145,:) - y(160,:) - y(175,:) - y(190,:) - y(205,:) - y(220,:) - y(229,:) - y(244,:) - y(259,:) - y(274,:) - y(289,:) - y(296,:))",
                "(- y(101,:) - y(116,:) - y(131,:) - y(146,:) - y(161,:) - y(176,:) - y(191,:) - y(206,:) - y(221,:) - y(230,:) - y(245,:) - y(260,:) - y(275,:) - y(290,:) - y(297,:))",
                "(- y(102,:) - y(103,:) - y(104,:) - y(117,:) - y(118,:) - y(119,:) - y(132,:) - y(133,:) - y(134,:) - y(147,:) - y(148,:) - y(149,:) - y(162,:) - y(231,:) - y(163,:) - y(232,:) - y(164,:) - y(233,:) - y(177,:) - y(246,:) - y(178,:) - y(247,:) - y(179,:) - y(248,:) - y(192,:) - y(261,:) - y(193,:) - y(262,:) - y(194,:) - y(263,:) - y(314,:) - y(315,:))",
                "(- y(105,:) - y(120,:) - y(135,:) - y(150,:) - y(165,:) - y(180,:) - y(195,:) - y(210,:) - y(222,:) - y(234,:) - y(249,:) - y(264,:) - y(279,:) - y(291,:) - y(106,:) - y(121,:) - y(136,:) - y(151,:) - y(166,:) - y(181,:) - y(196,:) - y(211,:) - y(223,:) - y(235,:) - y(250,:) - y(265,:) - y(280,:) - y(292,:) - y(301,:) - y(299,:))",
                "", "", "", "", "", "", "\n", "\n", "\n", "\n", ""]

find_replace_in_file4(input_file, output_file, old_str_list, new_str_list)

find_replace_in_file5(input_file, output_file)
